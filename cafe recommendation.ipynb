# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
reviews=pd.read_csv("reviews.csv")
data=reviews.copy()
reviews.head()
reviews.tail()
# Out:
#      Index               Name Overall_Rating  \
# 827    827  Humming bird cafe            3.9
# 828    828           Roast 26            3.9
# 829    829       Olive Bistro            4.2
# 830    830            Hoppery            4.1
# 831    831       Elite bistro            4.2
#
#                                                Cuisine Rate for two  \
# 827  Cafe, Pizza, Continental, Italian, Bakery, Bev...        1,100
# 828  Cafe, Pizza, Continental, Italian, Bakery, Bev...        1,400
# 829  Cafe, Shake, Beverages, Waffle, Bakery, Desser...        1,400
# 830  Cafe, Coffee, Shake, Beverages, Sandwich, Past...         1200
# 831  Cafe, Coffee, Shake, Beverages, Sandwich, Past...         1400
#
#           City                                             Review
# 827  hyderabad                                   undercooked food
# 828  hyderabad  Yup, that's worth INR 410. Unbelievable less q...
# 829  hyderabad                                   Not even lit hot
# 830  hyderabad  Cappuccino tasted really bad, had a burnt tast...
# 831  hyderabad  For a coffee place, the coffee definitely fall...

# %%
#data cleansing
reviews.duplicated().sum()
reviews.drop_duplicates(inplace=True)

reviews.isnull().sum()
reviews.dropna(how='any', inplace=True)
reviews = reviews.rename(columns={'Rate for two':'cost','Overall_Rating':'rating'})
reviews['City'].describe
# Out:
# <bound method NDFrame.describe of 0      ahmedabad
# 1      ahmedabad
# 2      ahmedabad
# 3      ahmedabad
# 4      ahmedabad
#          ...
# 827    hyderabad
# 828    hyderabad
# 829    hyderabad
# 830    hyderabad
# 831    hyderabad
# Name: City, Length: 832, dtype: object>

# %%
reviews['cost'] = pd.to_numeric(reviews['cost'], errors='coerce')
default_value = 0  # You can choose a different default value
reviews['cost'].fillna(default_value, inplace=True)
reviews['cost'] = reviews['cost'].astype(str) #Changing the cost to string
reviews['cost'] = reviews['cost'].apply(lambda x: x.replace(',','')) #Using lambda function to replace ',' from cost
reviews['cost']=reviews['cost'].astype(float)
reviews['rating'] = pd.to_numeric(reviews['rating'], errors='coerce')

# Drop rows with missing values (NaN)
reviews = reviews.dropna()

# %%
scaler = MinMaxScaler()
reviews[['rating', 'cost']] = scaler.fit_transform(reviews[['rating', 'cost']])

# %%
feature_columns = ['rating', 'cost']
vectors = reviews[feature_columns].values

# %%
cosine_sim_mat=cosine_similarity(vectors,vectors)

# %%
target_cafe_index = 0
similar_cafes_indices = sorted(range(len(cosine_sim_mat[target_cafe_index])), key=lambda k: cosine_sim_mat[target_cafe_index][k], reverse=True)[1:]
recommended_cafes = reviews.iloc[similar_cafes_indices]

# %%
print(recommended_cafes[['Name', 'rating', 'cost']])
# Out:
#                   Name    rating      cost
# 1         Oliver Brown  0.583333  0.357143
# 41   Indie Brewed Cafe  0.583333  0.357143
# 42   Indie Brewed Cafe  0.583333  0.357143
# 43   Indie Brewed Cafe  0.583333  0.357143
# 63         Cafe Selfie  0.583333  0.357143
# ..                 ...       ...       ...
# 522         Cafe Diona  0.041667  0.678571
# 397        Narcos Cafe  0.000000  0.357143
# 398        Narcos Cafe  0.000000  0.357143
# 399        Narcos Cafe  0.000000  0.357143
# 400        Narcos Cafe  0.000000  0.357143
#
# [714 rows x 3 columns]

# %%
recommended_cafes
# Out:
#      Index               Name    rating  \
# 1        1       Oliver Brown  0.583333
# 41      41  Indie Brewed Cafe  0.583333
# 42      42  Indie Brewed Cafe  0.583333
# 43      43  Indie Brewed Cafe  0.583333
# 63      63        Cafe Selfie  0.583333
# ..     ...                ...       ...
# 522    522         Cafe Diona  0.041667
# 397    397        Narcos Cafe  0.000000
# 398    398        Narcos Cafe  0.000000
# 399    399        Narcos Cafe  0.000000
# 400    400        Narcos Cafe  0.000000
#
#                                                Cuisine      cost       City  \
# 1    Cafe, Coffee, Shake, Juices, Beverages, Waffle...  0.357143  ahmedabad
# 41           Cafe, Coffee, Shake, Beverages, Fast Food  0.357143  ahmedabad
# 42           Cafe, Coffee, Shake, Beverages, Fast Food  0.357143  ahmedabad
# 43           Cafe, Coffee, Shake, Beverages, Fast Food  0.357143  ahmedabad
# 63                   Cafe, Beverages, Shake, Fast Food  0.357143  ahmedabad
# ..                                                 ...       ...        ...
# 522  Cafe, North Indian, Chinese, Continental, Fast...  0.678571     jaipur
# 397                 Cafe, Fast Food, Coffee, Beverages  0.357143  bangalore
# 398                 Cafe, Fast Food, Coffee, Beverages  0.357143  bangalore
# 399                 Cafe, Fast Food, Coffee, Beverages  0.357143  bangalore
# 400                 Cafe, Fast Food, Coffee, Beverages  0.357143  bangalore
#
#                                                 Review
# 1    I recently visited Oliver Brown on a weekend f...
# 41        Very bad iced AmericanoDon’t order from here
# 42   Ordered from here thrice. I love what they off...
# 43   There is no ice in peach iced tea in fact it i...
# 63                                          vary small
# ..                                                 ...
# 522  First they charge you so much for a couple ent...
# 397  If you want to waste time and money, go here! ...
# 398  This review is for the one at ITC factory, my ...
# 399  They claim to be open for breakfast at 9am. We...
# 400  Liked the ambience but the service was quite l...
#
# [714 rows x 7 columns]

# %%
new_dataset=recommended_cafes[['Name','cost','rating']].copy()
new_dataset.duplicated().sum()
new_dataset
# Out:
#                   Name      cost    rating
# 1         Oliver Brown  0.357143  0.583333
# 41   Indie Brewed Cafe  0.357143  0.583333
# 42   Indie Brewed Cafe  0.357143  0.583333
# 43   Indie Brewed Cafe  0.357143  0.583333
# 63         Cafe Selfie  0.357143  0.583333
# ..                 ...       ...       ...
# 522         Cafe Diona  0.678571  0.041667
# 397        Narcos Cafe  0.357143  0.000000
# 398        Narcos Cafe  0.357143  0.000000
# 399        Narcos Cafe  0.357143  0.000000
# 400        Narcos Cafe  0.357143  0.000000
#
# [714 rows x 3 columns]

# %%
new_dataset.drop_duplicates(inplace=True)

# %%
new_dataset
# Out:
#                            Name      cost    rating
# 1                  Oliver Brown  0.357143  0.583333
# 41            Indie Brewed Cafe  0.357143  0.583333
# 63                  Cafe Selfie  0.357143  0.583333
# 68                   Busy Beans  0.357143  0.583333
# 149  Hustle Snooker Cafe Bistro  0.357143  0.583333
# ..                          ...       ...       ...
# 134              Back To Basics  0.500000  0.125000
# 215               Cafe Cremyday  0.357143  0.083333
# 394              Cafe Centralis  0.678571  0.125000
# 521                  Cafe Diona  0.678571  0.041667
# 397                 Narcos Cafe  0.357143  0.000000
#
# [313 rows x 3 columns]

# %%
merged_df = pd.merge(new_dataset, data, left_index=True, right_index=True)
merged_df.drop(columns=['Name_y'], inplace=True)

# %%
merged_df.rename(columns={'Name_x':'Name'},inplace=True)
merged_df
# Out:
#                            Name      cost    rating  Index Overall_Rating  \
# 1                  Oliver Brown  0.357143  0.583333      1            3.9
# 41            Indie Brewed Cafe  0.357143  0.583333     41            3.9
# 63                  Cafe Selfie  0.357143  0.583333     63            3.9
# 68                   Busy Beans  0.357143  0.583333     68            3.9
# 149  Hustle Snooker Cafe Bistro  0.357143  0.583333    149            3.9
# ..                          ...       ...       ...    ...            ...
# 134              Back To Basics  0.500000  0.125000    134            2.8
# 215               Cafe Cremyday  0.357143  0.083333    215            2.7
# 394              Cafe Centralis  0.678571  0.125000    394            2.8
# 521                  Cafe Diona  0.678571  0.041667    521            2.6
# 397                 Narcos Cafe  0.357143  0.000000    397            2.5
#
#                                                Cuisine Rate for two  \
# 1    Cafe, Coffee, Shake, Juices, Beverages, Waffle...          500
# 41           Cafe, Coffee, Shake, Beverages, Fast Food          500
# 63                   Cafe, Beverages, Shake, Fast Food          500
# 68                          Cafe, Beverages, Fast Food          500
# 149  Cafe, Coffee, Sandwich, Pizza, Burger, Fast Fo...          500
# ..                                                 ...          ...
# 134  Cafe, Coffee, Beverages, Sandwich, Fast Food, ...          700
# 215  Cafe, Fast Food, Desserts, Beverages, Street F...          500
# 394                    Cafe, Chinese, Italian, Sichuan          950
# 521  Cafe, North Indian, Chinese, Continental, Fast...          950
# 397                 Cafe, Fast Food, Coffee, Beverages          500
#
#           City                                             Review
# 1    ahmedabad  I recently visited Oliver Brown on a weekend f...
# 41   ahmedabad       Very bad iced AmericanoDon’t order from here
# 63   ahmedabad                                         vary small
# 68   ahmedabad  Pure coffee  beans test and delicious...Good q...
# 149       pune  the pizza was cold and not in good shape and w...
# ..         ...                                                ...
# 134       pune  food food food at it's best! ambience at it's ...
# 215       pune  My friend visited this outlet yesterday to eat...
# 394  bangalore  One of the best place to visit they serve one ...
# 521     jaipur  The staff is very rude. They do not have hotel...
# 397  bangalore  If you want to waste time and money, go here! ...
#
# [313 rows x 9 columns]

# %%
final_data=merged_df[['Name','Overall_Rating','Cuisine','Rate for two','City']].copy()

# %%
final_data.duplicated().sum()
final_data.isnull().sum()
# Out:
# Name              0
# Overall_Rating    0
# Cuisine           0
# Rate for two      0
# City              0
# dtype: int64

# %%
final_data.drop_duplicates(inplace=True)
final_data
# Out:
#                            Name Overall_Rating  \
# 1                  Oliver Brown            3.9
# 41            Indie Brewed Cafe            3.9
# 63                  Cafe Selfie            3.9
# 68                   Busy Beans            3.9
# 149  Hustle Snooker Cafe Bistro            3.9
# ..                          ...            ...
# 134              Back To Basics            2.8
# 215               Cafe Cremyday            2.7
# 394              Cafe Centralis            2.8
# 521                  Cafe Diona            2.6
# 397                 Narcos Cafe            2.5
#
#                                                Cuisine Rate for two       City
# 1    Cafe, Coffee, Shake, Juices, Beverages, Waffle...          500  ahmedabad
# 41           Cafe, Coffee, Shake, Beverages, Fast Food          500  ahmedabad
# 63                   Cafe, Beverages, Shake, Fast Food          500  ahmedabad
# 68                          Cafe, Beverages, Fast Food          500  ahmedabad
# 149  Cafe, Coffee, Sandwich, Pizza, Burger, Fast Fo...          500       pune
# ..                                                 ...          ...        ...
# 134  Cafe, Coffee, Beverages, Sandwich, Fast Food, ...          700       pune
# 215  Cafe, Fast Food, Desserts, Beverages, Street F...          500       pune
# 394                    Cafe, Chinese, Italian, Sichuan          950  bangalore
# 521  Cafe, North Indian, Chinese, Continental, Fast...          950     jaipur
# 397                 Cafe, Fast Food, Coffee, Beverages          500  bangalore
#
# [313 rows x 5 columns]

# %%
def search_city(city_name):
    cafes_in_city = final_data[final_data['City'].str.lower() == city_name.lower()]
    return cafes_in_city

# %%
cafes_in_city=search_city('jaipur')
cafes_in_city
# Out:
#                                  Name Overall_Rating  \
# 482                             Jashn            3.9
# 546                      Malgudi Cafe              4
# 530                    Viona Baristro            3.6
# 444                     Terra Gourmet            4.2
# 447             Roastery Coffee House            4.5
# 457                       Brown Sugar            4.2
# 442                    The Waffle Co.            3.9
# 557                     Lloyd's House            3.9
# 435                    Barista Coffee            4.1
# 455                     Bombaye House            4.1
# 548            Royal Bakery Cafeteria            3.8
# 488                     Starstud Cafe              4
# 526             Loca By La Multigrain              4
# 511              Sweet Dough By Kanha            3.5
# 555   Legacy Terrace Cafe And Kitchen            3.7
# 468                          Assamica            4.3
# 486                      Aakraa House            3.8
# 537                     Cafe Two Pi R            3.8
# 492                      Coffee Sutra            3.7
# 565               Team 11 Sports Cafe            3.6
# 562                   Crush On Coffee            3.4
# 494                       Quyu's Cafe            4.2
# 523                    House Of Beans            4.1
# 503                             Chska            3.5
# 566                       Cafe Kampus            3.3
# 518                  The Over Halt In              3
# 512                         Half Brew            3.5
# 560       TRCH-Luxury Restro & Lounge            3.5
# 436    Camiano Patisserie & Brasserie            4.5
# 437                      Kaleidoscope              4
# 452                    Chum-Bakk Cafe            4.3
# 463     Zolocrust - Hotel Clarks Amer            4.8
# 471            Uphoria- Cafe & Restro            3.8
# 472           Alora Cafe & Patisserie            3.2
# 477               The Messy Door Cafe            3.6
# 496  Cafe Cornerstone By Pallavi Daga            2.9
# 499                         The-Gorma            4.3
# 501                   Coffee. Connect            4.4
# 541                    Coffee Network            3.8
# 552                The Chocolate Room              3
# 568                 SST Cakes & Bakes            2.9
# 508                        Phele Chai            2.7
# 521                        Cafe Diona            2.6
#
#                                                Cuisine Rate for two    City
# 482  Cafe, Coffee, Fast Food, Street Food, North In...          500  jaipur
# 546  Cafe, Italian, Chinese, Fast Food, Beverages, ...          500  jaipur
# 530  Cafe, Street Food, Chinese, Pizza, Fast Food, ...          350  jaipur
# 444  Cafe, Coffee, Continental, Fast Food, Pasta, L...          700  jaipur
    final_data['Rate for two'] = final_data['Rate for two'].str.replace(',', '').astype(float)
    cafes_in_price_range = final_data[
        (final_data['Rate for two'] >= min_price) & 
        (final_data['Rate for two'] <= max_price)
    ]
    return cafes_in_price_range

# %%
cafes_in_price_range=cost_cafes(500,1200)

# %%
cafes_in_price_range
# Out:
#                            Name Overall_Rating  \
# 1                  Oliver Brown            3.9
# 41            Indie Brewed Cafe            3.9
# 63                  Cafe Selfie            3.9
# 68                   Busy Beans            3.9
# 149  Hustle Snooker Cafe Bistro            3.9
# ..                          ...            ...
# 134              Back To Basics            2.8
# 215               Cafe Cremyday            2.7
# 394              Cafe Centralis            2.8
# 521                  Cafe Diona            2.6
# 397                 Narcos Cafe            2.5
#
#                                                Cuisine  Rate for two  \
# 1    Cafe, Coffee, Shake, Juices, Beverages, Waffle...         500.0
# 41           Cafe, Coffee, Shake, Beverages, Fast Food         500.0
# 63                   Cafe, Beverages, Shake, Fast Food         500.0
# 68                          Cafe, Beverages, Fast Food         500.0
# 149  Cafe, Coffee, Sandwich, Pizza, Burger, Fast Fo...         500.0
# ..                                                 ...           ...
# 134  Cafe, Coffee, Beverages, Sandwich, Fast Food, ...         700.0
# 215  Cafe, Fast Food, Desserts, Beverages, Street F...         500.0
# 394                    Cafe, Chinese, Italian, Sichuan         950.0
# 521  Cafe, North Indian, Chinese, Continental, Fast...         950.0
# 397                 Cafe, Fast Food, Coffee, Beverages         500.0
#
#           City
# 1    ahmedabad
# 41   ahmedabad
# 63   ahmedabad
# 68   ahmedabad
# 149       pune
# ..         ...
# 134       pune
# 215       pune
# 394  bangalore
# 521     jaipur
# 397  bangalore
#
# [247 rows x 5 columns]

# %%
common_data = cafes_in_city[cafes_in_city.index.isin(cafes_in_price_range.index)]

# %%
common_data
# Out:
#                                  Name Overall_Rating  \
# 482                             Jashn            3.9
# 546                      Malgudi Cafe              4
# 444                     Terra Gourmet            4.2
# 447             Roastery Coffee House            4.5
# 457                       Brown Sugar            4.2
# 442                    The Waffle Co.            3.9
# 435                    Barista Coffee            4.1
# 455                     Bombaye House            4.1
# 488                     Starstud Cafe              4
# 526             Loca By La Multigrain              4
# 511              Sweet Dough By Kanha            3.5
# 555   Legacy Terrace Cafe And Kitchen            3.7
# 468                          Assamica            4.3
# 486                      Aakraa House            3.8
# 537                     Cafe Two Pi R            3.8
# 492                      Coffee Sutra            3.7
# 565               Team 11 Sports Cafe            3.6
# 562                   Crush On Coffee            3.4
# 494                       Quyu's Cafe            4.2
# 523                    House Of Beans            4.1
# 503                             Chska            3.5
# 566                       Cafe Kampus            3.3
# 512                         Half Brew            3.5
# 560       TRCH-Luxury Restro & Lounge            3.5
# 436    Camiano Patisserie & Brasserie            4.5
# 437                      Kaleidoscope              4
# 452                    Chum-Bakk Cafe            4.3
# 471            Uphoria- Cafe & Restro            3.8
# 472           Alora Cafe & Patisserie            3.2
# 477               The Messy Door Cafe            3.6
# 496  Cafe Cornerstone By Pallavi Daga            2.9
# 499                         The-Gorma            4.3
